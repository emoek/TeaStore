# %%
import json
import csv
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

print("Hello")
# Out:
# Hello

# %%
"""PATH OPERATIONS"""
path_cycles_webui_1 = "../results/resultv21/exp8_0_0_collect_cyclesWebUI_1.csv"
path_cycles_webui_2 = "../results/resultv21/exp8_0_0_collect_cyclesWebUI_2.csv"
path_cycles_webui_3 = "../results/resultv21/exp8_0_0_collect_cyclesWebUI_3.csv"

path_instr_all_1 = "../results/resultv21/exp8_0_0_collect_instrAll_1.csv"
path_instr_all_2 = "../results/resultv21/exp8_0_0_collect_instrAll_2.csv"
path_instr_all_3 = "../results/resultv21/exp8_0_0_collect_instrAll_3.csv"

path_instr_webui_1 = "../results/resultv21/exp8_0_0_collect_instrWebUI_1.csv"
path_instr_webui_2 = "../results/resultv21/exp8_0_0_collect_instrWebUI_2.csv"
path_instr_webui_3 = "../results/resultv21/exp8_0_0_collect_instrWebUI_3.csv"

path_power_package_all_1 = "../results/resultv21/exp8_0_0_collect_powerConsPackageAll_1.csv"
path_power_package_all_2 = "../results/resultv21/exp8_0_0_collect_powerConsPackageAll_2.csv"
path_power_package_all_3 = "../results/resultv21/exp8_0_0_collect_powerConsPackageAll_3.csv"

path_power_packageram_all_1 = "../results/resultv21/exp8_0_0_collect_powerConsPackageRAMAll_1.csv"
path_power_packageram_all_2 = "../results/resultv21/exp8_0_0_collect_powerConsPackageRAMAll_2.csv"
path_power_packageram_all_3 = "../results/resultv21/exp8_0_0_collect_powerConsPackageRAMAll_3.csv"

path_power_packageram_webui_1 = "../results/resultv21/exp8_0_0_collect_powerConsPackageRAMWebUI_1.csv"
path_power_packageram_webui_2 = "../results/resultv21/exp8_0_0_collect_powerConsPackageRAMWebUI_2.csv"
path_power_packageram_webui_3 = "../results/resultv21/exp8_0_0_collect_powerConsPackageRAMWebUI_3.csv"

path_power_package_webui_1 = "../results/resultv21/exp8_0_0_collect_powerConsWebUI_1.csv"
path_power_package_webui_2 = "../results/resultv21/exp8_0_0_collect_powerConsWebUI_2.csv"
path_power_package_webui_3 = "../results/resultv21/exp8_0_0_collect_powerConsWebUI_3.csv"

path_power_node_1 = "../results/resultv21/exp8_10_1_generic_nodePower_1.csv"
path_power_node_2 = "../results/resultv21/exp8_10_1_generic_nodePower_2.csv"
path_power_node_3 = "../results/resultv21/exp8_10_1_generic_nodePower_3.csv"

# %%
instr_webui_1 = 0
power_package_webui_1 = 0
with open(path_instr_all_3, newline='') as f:
    reader = csv.reader(f)
    instr_webui_1  = list(reader)


with open(path_power_packageram_all_3, newline='') as f:
    reader = csv.reader(f)
    power_package_webui_1 = list(reader)

instr_webui_1 = [float(row[2]) for row in instr_webui_1[1:]]  # skip the first item as it's headers
power_package_webui_1 = [float(row[2]) for row in power_package_webui_1[1:]]  # skip the first item as it's headers



print(instr_webui_1)

print(power_package_webui_1)

avg_instr = np.mean(instr_webui_1)
avg_power = np.mean(power_package_webui_1)
 

corr = np.corrcoef(power_package_webui_1, instr_webui_1)[0,1]

print("avg_instr:", avg_instr)
print("avg_power:", avg_power)
print("corr:",corr)
# Out:
# [2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 2975776826.7, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 738348502.1333333, 1308812347.8999999, 1308812347.8999999, 1308812347.8999999, 1308812347.899999
# ...
